# %% [markdown]
# ### About the dataset (Health Insurance Data)
#
# The dataset contains information about 1300 individuals regarding insurance charges. The data contains an individual's basic information like age, sex, bmi, the region of residence and so on.
#
# Attribute Information:
#
# **age**: Age of the individual
#
# **gender**: Gender of the individual
#
# **bmi**: Body mass index of the individual
#
# **bp**: Systolic blood pressure in mm/hg
#
# **children**: Number of children of the individual
#
# **smoker**: Individual is smoker or not
#
# **region**: Individual's region of residence
#
# **medical_cost**: Individual's medical costs billed by the insurance company

# %% [markdown]
# ##  Table of Content
#
# 1. **[Univariate Analysis](#uni)**
# 2. **[Multivariate Analysis](#multi)**
# 3. **[Handle Non-Numeric Data](#cat)**
# 4. **[Normalization](#norm)**
# 5. **[Transformation Techniques](#trans)**

# %% [markdown]
# **Import the required libraries**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #### Load the health insurance dataset and check the first five observations

# %%
df=pd.read_csv('health_insurance.csv')

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="uni"> </a>
# ## 1. Univariate Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Are there any extreme observations present in 'bmi'? Support your answer with a plot
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
import seaborn as sns

# %%
sns.boxplot(df['bmi'])
# Out:
# C:\Users\tsskr\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi'>

# %%
#yes there are extreme values present in bmi attribute and they are present above 50 bmi value on right side.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Is the variable 'age' skewed? Support your answer with a plot and metric</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df['age'].skew()
# Out:
# 0.04359793424360781

# %%
sns.distplot(df['age'])
# Out:
# C:\Users\tsskr\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. What is the probability that the individuals have charged less than 25k for medical treatment? Support your answer with the plot</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df['medical_cost'].describe()
# Out:
# count     1300.000000
# mean     13243.214691
# std      12060.371167
# min       1121.873900
# 25%       4760.155950
# 50%       9388.753650
# 75%      16579.959053
# max      63770.428010
# Name: medical_cost, dtype: float64

# %%
df_1 = df[df['medical_cost']<=25000]

# %%
df_1['medical_cost'].describe()
# Out:
# count     1108.000000
# mean      8916.243415
# std       5773.000513
# min       1121.873900
# 25%       4314.375937
# 50%       8027.317300
# 75%      12132.855262
# max      24915.220850
# Name: medical_cost, dtype: float64

# %%
1108/1300
# Out:
# 0.8523076923076923

# %%
sns.distplot(df['medical_cost'])
# Out:
# C:\Users\tsskr\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='medical_cost', ylabel='Density'>

# %%
sns.distplot(df['medical_cost'],hist_kws=dict(cumulative=True),kde_kws=dict(cumulative=True))
# Out:
# C:\Users\tsskr\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='medical_cost', ylabel='Density'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Draw the line for mean and median on the distribution plot and identify the type of skewness for BMI</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df['bmi'].skew()
# Out:
# 0.2496769760401315

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['bmi'])
plt.axvline(df['bmi'].mean(),color='red')
plt.axvline(df['bmi'].median(),color='white')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Visualize the distribution of medical cost using violin plot and describe its distribution</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.violinplot(df['medical_cost'])
# Out:
# C:\Users\tsskr\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='medical_cost'>

# %% [markdown]
# <a id="multi"> </a>
# ## 2. Multivariate Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there any individual with age less than 30 and meadical cost greater than 40k?
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df[(df['age']<30)  & (df['medical_cost']>40000)]

#yes there are three people
# Out:
#       age gender    bmi  bp   children     region  smoker  medical_cost
# 254    26      F  47.54  156         2  northeast  smoker    42112.2356
# 1009   25      F  55.58  152         1  northeast  smoker    44501.3982
# 1086   26      M  41.75  152         1  northeast  smoker    40904.1995

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Does the scatter plot of BMI and medical cost reveal potential outliers?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.scatterplot(data=df,x='bmi',y='medical_cost')
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='medical_cost'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Determine the percentage variation in BMI for males and females
#
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sigma = df.groupby('gender')['bmi'].std()
mu = df.groupby('gender')['bmi'].mean()
cv=sigma/mu
cv
# Out:
# gender
# F    0.201200
# M    0.201183
# Name: bmi, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Which region has the highest number of males?
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.crosstab(df['gender'],df['region']).plot(kind='bar')

#south east has highest female and male
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
df.groupby('region')['gender'].count()
# Out:
# region
# northeast    315
# northwest    315
# southeast    356
# southwest    314
# Name: gender, dtype: int64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Analyze the pairwise relationship between the numeric variables
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.pairplot(df)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Are the medical costs affected by an individual's smoking habits?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.boxplot(df['smoker'],df['medical_cost'])
# Out:
# C:\Users\tsskr\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='medical_cost'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Check if the region of residence and age of the individuals have an impact on the medical cost? </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.scatterplot(df['age'],df['medical_cost'],df['region'])

#age dosesnt have do not affect on medical cost
# Out:
# C:\Users\tsskr\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='medical_cost'>

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Handle Non-Numeric Data

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Create a dummy variable for each category in 'region'
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Create a variable 'smoker_label' containing unique label for each category in the variable 'smoker'
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df=pd.read_csv('health_insurance.csv')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Create a variable which will contain the frequency of an individual's gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df['freq_gender']=df['gender'].value_counts()/len(df)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Create a variable such that the value '1' indicates that the individual is a smoker and '0' indicates a non-smoker</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()

# %%
df['LE_smoker']=LE.fit_transform(df['smoker'])

# %%
df['LE_smoker']
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1295    0
# 1296    0
# 1297    0
# 1298    0
# 1299    1
# Name: LE_smoker, Length: 1300, dtype: int32

# %% [markdown]
# <a id="norm"> </a>
# ## 4. Normalization

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Transform BMI such that it will have mean zero and variance one</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.columns
# Out:
# Index(['age', 'gender', 'bmi', 'bp ', 'children', 'region', 'smoker',
#        'medical_cost', 'freq_gender', 'LE_smoker'],
#       dtype='object')

# %%
#mean = 0
#std = 1
from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
df['SS_BMI']=SS.fit_transform(df[['bmi']])

# %%
df['SS_BMI']
# Out:
# 0       0.050142
# 1       0.816583
# 2       0.538020
# 3      -1.239588
# 4      -0.582526
#           ...
# 1295   -0.096222
# 1296    0.525430
# 1297    0.514413
# 1298   -1.067257
# 1299    0.234277
# Name: SS_BMI, Length: 1300, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. Check the range of 'age' and transform the values such that the range will be 1</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
from sklearn.preprocessing import MinMaxScaler
MM=MinMaxScaler()
df['MMS_age']=MM.fit_transform(df[['age']])

# %%
df['MMS_age']
# Out:
# 0       0.08
# 1       0.02
# 2       0.28
# 3       0.36
# 4       0.34
#         ...
# 1295    0.70
# 1296    0.06
# 1297    0.04
# 1298    0.06
# 1299    0.88
# Name: MMS_age, Length: 1300, dtype: float64

# %% [markdown]
# <a id="trans"> </a>
# ## 5. Transformation Techniques

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. Check the skewness for 'medical_cost'. If the data is skewed, then use the appropriate technique to reduce the skewness in the data
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.distplot(df['medical_cost'])
# Out:
# C:\Users\tsskr\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='medical_cost', ylabel='Density'>

# %%
df['sqrt_medical_cost']=np.log(df['medical_cost'])

# %%
sns.distplot(df['sqrt_medical_cost'])
# Out:
# C:\Users\tsskr\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sqrt_medical_cost', ylabel='Density'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Transform the 'log_medical_cost' values to the original scale and compare the 'medical_cost' and the transformed data</b>
#                 </font>
#             </div>
#
# </td>
#     </tr>
# </table>

# %%
sns.distplot(df['medical_cost'])
# Out:
# C:\Users\tsskr\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='medical_cost', ylabel='Density'>

# %%
df['log_medical_cost']=np.log(df['medical_cost'])

# %%
df['log_medical_cost'].describe()
# Out:
# count    1300.000000
# mean        9.100269
# std         0.914830
# min         7.022756
# 25%         8.468035
# 50%         9.147268
# 75%         9.715950
# max        11.063045
# Name: log_medical_cost, dtype: float64

# %%
df['medical_cost'].replace(to_replace=0,value=df['medical_cost'].median(),inplace=True)

# %%
df['log_medical_cost'] =np.log(df['medical_cost'])
